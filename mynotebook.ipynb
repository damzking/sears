# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_4.csv")

# %%
df.head()
# Out:
#   Attribute   Value    Date_GBP    Date_usd    Date_EUR Day Name_fOR_USD  \
# 0       EUR   0.950  13/08/2014  14/05/2014  06/08/2014        Wednesday
# 1       EUR  92.384  23/03/2009  03/12/2008  18/03/2009        Wednesday
# 2       EUR  93.679  14/11/2008  19/08/2008  13/11/2008          Tuesday
# 3       EUR  93.859  21/11/2008  20/08/2008  14/11/2008        Wednesday
# 4       EUR  93.922  04/11/2008  11/08/2008  29/10/2008           Monday
#
#   Day_ Name_EUR Day_Name_GBP
# 0     Wednesday    Wednesday
# 1     Wednesday       Monday
# 2      Thursday       Friday
# 3        Friday       Friday
# 4     Wednesday      Tuesday

# %%
df.describe(include='all')
# Out:
#        Attribute         Value    Date_GBP    Date_usd    Date_EUR  \
# count      14339  14339.000000       14270       14339       14278
# unique         3           NaN        4760        4825        4764
# top          USD           NaN  13/08/2014  14/05/2014  06/08/2014
# freq        4823           NaN           3           3           3
# mean         NaN    272.226059         NaN         NaN         NaN
# std          NaN    914.341470         NaN         NaN         NaN
# min          NaN      0.950000         NaN         NaN         NaN
# 25%          NaN    108.644150         NaN         NaN         NaN
# 50%          NaN    151.750000         NaN         NaN         NaN
# 75%          NaN    354.938000         NaN         NaN         NaN
# max          NaN  75214.000000         NaN         NaN         NaN
#
#        Day Name_fOR_USD Day_ Name_EUR Day_Name_GBP
# count             14339         14278        14270
# unique                7             7            7
# top            Thursday     Wednesday    Wednesday
# freq               2922          2912         2913
# mean                NaN           NaN          NaN
# std                 NaN           NaN          NaN
# min                 NaN           NaN          NaN
# 25%                 NaN           NaN          NaN
# 50%                 NaN           NaN          NaN
# 75%                 NaN           NaN          NaN
# max                 NaN           NaN          NaN

# %%
df
# Out:
#       Attribute      Value    Date_GBP    Date_usd    Date_EUR  \
# 0           EUR      0.950  13/08/2014  14/05/2014  06/08/2014
# 1           EUR     92.384  23/03/2009  03/12/2008  18/03/2009
# 2           EUR     93.679  14/11/2008  19/08/2008  13/11/2008
# 3           EUR     93.859  21/11/2008  20/08/2008  14/11/2008
# 4           EUR     93.922  04/11/2008  11/08/2008  29/10/2008
# ...         ...        ...         ...         ...         ...
# 14334       USD    827.793         NaN  30/11/2023         NaN
# 14335       USD    827.793         NaN  28/11/2023         NaN
# 14336       USD    827.793         NaN  29/11/2023         NaN
# 14337       USD  75207.000  12/03/2009  20/11/2008  06/03/2009
# 14338       USD  75214.000  28/01/2009  03/10/2008  27/01/2009
#
#       Day Name_fOR_USD Day_ Name_EUR Day_Name_GBP
# 0            Wednesday     Wednesday    Wednesday
# 1            Wednesday     Wednesday       Monday
# 2              Tuesday      Thursday       Friday
# 3            Wednesday        Friday       Friday
# 4               Monday     Wednesday      Tuesday
# ...                ...           ...          ...
# 14334         Thursday           NaN          NaN
# 14335          Tuesday           NaN          NaN
# 14336        Wednesday           NaN          NaN
# 14337         Thursday        Friday     Thursday
# 14338           Friday       Tuesday    Wednesday
#
# [14339 rows x 8 columns]

# %%
df[df.isna()]
# Out:
#       Attribute  Value Date_GBP Date_usd Date_EUR Day Name_fOR_USD  \
# 0           NaN    NaN      NaN      NaN      NaN              NaN
# 1           NaN    NaN      NaN      NaN      NaN              NaN
# 2           NaN    NaN      NaN      NaN      NaN              NaN
# 3           NaN    NaN      NaN      NaN      NaN              NaN
# 4           NaN    NaN      NaN      NaN      NaN              NaN
# ...         ...    ...      ...      ...      ...              ...
# 14334       NaN    NaN      NaN      NaN      NaN              NaN
# 14335       NaN    NaN      NaN      NaN      NaN              NaN
# 14336       NaN    NaN      NaN      NaN      NaN              NaN
# 14337       NaN    NaN      NaN      NaN      NaN              NaN
# 14338       NaN    NaN      NaN      NaN      NaN              NaN
#
#       Day_ Name_EUR Day_Name_GBP
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ...             ...          ...
# 14334           NaN          NaN
# 14335           NaN          NaN
# 14336           NaN          NaN
# 14337           NaN          NaN
# 14338           NaN          NaN
#
# [14339 rows x 8 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#       Attribute    Value Date_GBP    Date_usd    Date_EUR Day Name_fOR_USD  \
# 4731        EUR  903.950      NaN  04/09/2023  30/11/2023           Monday
# 4739        EUR  906.763      NaN  30/08/2023  27/11/2023        Wednesday
# 4741        EUR  907.261      NaN  31/08/2023  28/11/2023         Thursday
# 4746        EUR  909.165      NaN  01/09/2023  29/11/2023           Friday
# 14272       USD  825.001      NaN  01/09/2023  29/11/2023           Friday
# ...         ...      ...      ...         ...         ...              ...
# 14332       USD  827.716      NaN  21/11/2023         NaN          Tuesday
# 14333       USD  827.716      NaN  22/11/2023         NaN        Wednesday
# 14334       USD  827.793      NaN  30/11/2023         NaN         Thursday
# 14335       USD  827.793      NaN  28/11/2023         NaN          Tuesday
# 14336       USD  827.793      NaN  29/11/2023         NaN        Wednesday
#
#       Day_ Name_EUR Day_Name_GBP
# 4731       Thursday          NaN
# 4739         Monday          NaN
# 4741        Tuesday          NaN
# 4746      Wednesday          NaN
# 14272     Wednesday          NaN
# ...             ...          ...
# 14332           NaN          NaN
# 14333           NaN          NaN
# 14334           NaN          NaN
# 14335           NaN          NaN
# 14336           NaN          NaN
#
# [69 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Attribute            0
# Value                0
# Date_GBP            69
# Date_usd             0
# Date_EUR            61
# Day Name_fOR_USD     0
# Day_ Name_EUR       61
# Day_Name_GBP        69
# dtype: int64

# %%
df['Date_EUR'] = pd.to_datetime(df['Date_EUR'], format='%d/%m/%Y')

# %%
df['Date_usd'] = pd.to_datetime(df['Date_usd'], format='%d/%m/%Y')

# %%
df['Date_GBP'] = pd.to_datetime(df['Date_GBP'], format='%d/%m/%Y')

# %%
df.dtypes
# Out:
# Attribute                   object
# Value                      float64
# Date_GBP            datetime64[ns]
# Date_usd            datetime64[ns]
# Date_EUR            datetime64[ns]
# Day Name_fOR_USD            object
# Day_ Name_EUR               object
# Day_Name_GBP                object
# dtype: object
